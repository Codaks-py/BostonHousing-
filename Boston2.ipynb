# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('HousingData.csv')

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df = df.dropna()

# %%
X = df.drop(["MEDV"], axis = 1)
y = df.MEDV

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
print('X_train: ', X_train.shape)
print('X_test: ', X_test.shape)
print('y_train: ', y_train.shape)
print('y_test: ', y_test.shape)
# Out:
# X_train:  (275, 13)
# X_test:  (119, 13)
# y_train:  (275,)
# y_test:  (119,)

# %%
X_train.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
X_train.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
print('X_train: ', X_train.shape)
print('X_test: ', X_test.shape)
# Out:
# X_train:  (275, 13)
# X_test:  (119, 13)

# %%
X_train.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.169582  0.383903 -0.059724  0.411673 -0.171762  0.311741
# ZN      -0.169582  1.000000 -0.491864 -0.046899 -0.502466  0.367494 -0.549271
# INDUS    0.383903 -0.491864  1.000000  0.046148  0.760668 -0.389854  0.618999
# CHAS    -0.059724 -0.046899  0.046148  1.000000  0.053364  0.109422  0.071206
# NOX      0.411673 -0.502466  0.760668  0.053364  1.000000 -0.294433  0.705054
# RM      -0.171762  0.367494 -0.389854  0.109422 -0.294433  1.000000 -0.221643
# AGE      0.311741 -0.549271  0.618999  0.071206  0.705054 -0.221643  1.000000
# DIS     -0.354111  0.640467 -0.691608 -0.093009 -0.775989  0.204108 -0.743960
# RAD      0.586366 -0.279823  0.596865 -0.011101  0.624266 -0.219587  0.404341
# TAX      0.549031 -0.276494  0.719279 -0.049629  0.678376 -0.299629  0.453931
# PTRATIO  0.247385 -0.402546  0.388739 -0.098491  0.200829 -0.373461  0.236932
# ...

# %%
X_test.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.240532  0.413968 -0.026867  0.435719 -0.376260  0.420475
# ZN      -0.240532  1.000000 -0.593097  0.000870 -0.548593  0.290969 -0.612049
# INDUS    0.413968 -0.593097  1.000000  0.065610  0.766317 -0.447368  0.693181
# CHAS    -0.026867  0.000870  0.065610  1.000000  0.134751  0.067632  0.078738
# NOX      0.435719 -0.548593  0.766317  0.134751  1.000000 -0.370333  0.789642
# RM      -0.376260  0.290969 -0.447368  0.067632 -0.370333  1.000000 -0.311598
# AGE      0.420475 -0.612049  0.693181  0.078738  0.789642 -0.311598  1.000000
# DIS     -0.395941  0.662948 -0.704730 -0.104945 -0.752879  0.257669 -0.774007
# RAD      0.673286 -0.344260  0.577226  0.079048  0.633241 -0.281373  0.524965
# TAX      0.599652 -0.378315  0.760501  0.036159  0.681000 -0.384451  0.612529
# PTRATIO  0.315102 -0.467432  0.412308 -0.121206  0.229959 -0.433004  0.328230
# ...

# %%
sns.heatmap(data = X_train.corr())
plt.title('Correlation of Training Dataset')
# Out:
# Text(0.5, 1.0, 'Correlation of Training Dataset')

# %%
sns.heatmap(data = X_test.corr())
plt.title("Correlation of the Testing Dataset")
# Out:
# Text(0.5, 1.0, 'Correlation of the Testing Dataset')

# %%
def corre(X_train, thre):
    corr_cols = set()
    corr = X_train.corr()
    for i in range(len(corr.columns)):
        for j in range(i):
            if abs(corr.iloc[i,j]) > thre:
                cols = corr.columns[i]
                corr_cols.add(cols)
                
    return corr_cols

corre(X_train, 0.75)
# Out:
# {'DIS', 'NOX', 'TAX'}

# %%
def corre(X_test, thre):
    corr_cols = set()
    corr = X_test.corr()
    for i in range(len(corr.columns)):
        for j in range(i):
            if abs(corr.iloc[i,j]) > thre:
                cols = corr.columns[i]
                corr_cols.add(cols)
                
    return corr_cols

corre(X_test, 0.78)
# Out:
# {'AGE', 'TAX'}

# %%
X_train = X_train.drop(['DIS', 'TAX'], axis = 1)
X_test = X_test.drop(['DIS', 'TAX'], axis = 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
regr = LinearRegression()
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regr.score(X_test, y_test)
# Out:
# 0.7412490798851458

# %%
regr.score(X_train, y_train)
# Out:
# 0.7126444467640816

# %%
corr = df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr, annot=True, cmap='YlGnBu')
plt.show()
